# %% [markdown]
# <a href="https://colab.research.google.com/github/hymakorukonda/calculator/blob/main/MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/211_DL'
# Out:
# /content/gdrive/My Drive/211_DL

# %%
import numpy as np
import pandas as pd

# Load data
data=pd.read_csv('diabetes.csv')

data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Import LabelEncoder
from sklearn import preprocessing

# Creating labelEncoder
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
data['Pregnancies']=le.fit_transform(data['Pregnancies'])
data['BloodPressure']=le.fit_transform(data['BloodPressure'])

# %%
# Spliting data into Feature and
X=data[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']]
y=data['Outcome']

# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)  # 70% training and 30% test

# %%
# Import MLPClassifer
from sklearn.neural_network import MLPClassifier

# Create model object
clf = MLPClassifier(hidden_layer_sizes=(6,5),
                    random_state=5,
                    verbose=True,
                    learning_rate_init=0.01)

# Fit data onto the model
clf.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 3.80083825
# Iteration 2, loss = 2.82450268
# Iteration 3, loss = 2.04835253
# Iteration 4, loss = 1.56105672
# Iteration 5, loss = 1.35799553
# Iteration 6, loss = 1.11189320
# Iteration 7, loss = 1.07670768
# Iteration 8, loss = 0.95576733
# Iteration 9, loss = 0.88135900
# Iteration 10, loss = 0.77890995
# Iteration 11, loss = 0.73078582
# Iteration 12, loss = 0.67240550
# Iteration 13, loss = 0.70732567
# Iteration 14, loss = 0.68978005
# Iteration 15, loss = 0.68502972
# Iteration 16, loss = 0.66555312
# Iteration 17, loss = 0.66434416
# Iteration 18, loss = 0.64291444
# Iteration 19, loss = 0.66281985
# Iteration 20, loss = 0.63421604
# Iteration 21, loss = 0.62866583
# Iteration 22, loss = 0.62225704
# Iteration 23, loss = 0.62150807
# Iteration 24, loss = 0.61965686
# Iteration 25, loss = 0.61504725
# Iteration 26, loss = 0.62941487
# Iteration 27, loss = 0.61516060
# Iteration 28, loss = 0.61419037
# Iteration 29, loss = 0.60846085
# ...

# %%
# Make prediction on test dataset
ypred=clf.predict(X_test)

# Import accuracy score
from sklearn.metrics import accuracy_score

# Calcuate accuracy
accuracy_score(y_test,ypred)
# Out:
# 0.7619047619047619

# %%
from sklearn.metrics import confusion_matrix as sa
import seaborn as sns
sns.heatmap(sa(y_test,ypred),annot=True,fmt=' ')
# Out:
# <Axes: >
